# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv("data2.csv")

# %%
df1
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df1.dropna()
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df1["Age"]=df1["Year"].astype(int)

# %%
df1
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv("data_cleaning_sample.csv")

# %%
df1
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df1=df1.dropna()
df1
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
df1["Age"]=df1["Age"].astype("category")

# %%
df1
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      category
#  2   City       5 non-null      object
#  3   Gender     5 non-null      object
#  4   Email      5 non-null      object
#  5   Join Date  5 non-null      object
# dtypes: category(1), object(5)
# memory usage: 377.0+ bytes

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      category
#  2   City       5 non-null      object
#  3   Gender     5 non-null      object
#  4   Email      5 non-null      object
#  5   Join Date  5 non-null      object
# dtypes: category(1), object(5)
# memory usage: 377.0+ bytes

# %%
df1
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
df1["Join Date"]=pd.to_datetime(df1["Join Date"],format="%d-%m-%Y")

# %%
df1
# Out:
#     Name   Age         City Gender              Email  Join Date
# 0  Alice  25.0     New York      F  alice@example.com 2021-05-01
# 2    Bob  30.0  Los Angeles      M    bob@example.com 2020-06-15
# 4  David  22.0       Mumbai      M  david@example.com 2019-11-12
# 6  Alice  25.0     New York      F  alice@example.com 2021-05-01
# 7  Alice  25.0     New York      F  alice@example.com 2021-05-01

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      category
#  2   City       5 non-null      object
#  3   Gender     5 non-null      object
#  4   Email      5 non-null      object
#  5   Join Date  5 non-null      datetime64[ns]
# dtypes: category(1), datetime64[ns](1), object(4)
# memory usage: 377.0+ bytes

# %%
df1["Year"]=df1["Join Date"].dt.year

# %%
df1
# Out:
#     Name   Age         City Gender              Email  Join Date  Year
# 0  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com 2020-06-15  2020
# 4  David  22.0       Mumbai      M  david@example.com 2019-11-12  2019
# 6  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021
# 7  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021

# %%
df1["Month"]=df1["Join Date"].dt.month

# %%
df1
# Out:
#     Name   Age         City Gender              Email  Join Date  Year  Month
# 0  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021      5
# 2    Bob  30.0  Los Angeles      M    bob@example.com 2020-06-15  2020      6
# 4  David  22.0       Mumbai      M  david@example.com 2019-11-12  2019     11
# 6  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021      5
# 7  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021      5

# %%
df1["Month_Name"]=df1["Join Date"].dt.month_name()

# %%
df1
# Out:
#     Name   Age         City Gender              Email  Join Date  Year  Month  \
# 0  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021      5
# 2    Bob  30.0  Los Angeles      M    bob@example.com 2020-06-15  2020      6
# 4  David  22.0       Mumbai      M  david@example.com 2019-11-12  2019     11
# 6  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021      5
# 7  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021      5
#
#   Month_Name
# 0        May
# 2       June
# 4   November
# 6        May
# 7        May

# %%
df1["Day_Name"]=df1["Join Date"].dt.day_name()

# %%
df1
# Out:
#     Name   Age         City Gender              Email  Join Date  Year  Month  \
# 0  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021      5
# 2    Bob  30.0  Los Angeles      M    bob@example.com 2020-06-15  2020      6
# 4  David  22.0       Mumbai      M  david@example.com 2019-11-12  2019     11
# 6  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021      5
# 7  Alice  25.0     New York      F  alice@example.com 2021-05-01  2021      5
#
#   Month_Name  Day_Name
# 0        May  Saturday
# 2       June    Monday
# 4   November   Tuesday
# 6        May  Saturday
# 7        May  Saturday

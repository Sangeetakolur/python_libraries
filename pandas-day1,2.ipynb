# %%
! pip install pandas

# %% [markdown]
# # creating series

# %%
import pandas as pd

# %%
s1=pd.Series([1,2,3,4,5])

# %%
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1=pd.Series([1,2,3,4,],index=["a","b","c","d"])

# %%
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data={"Name":["Alice","bob","charlie"],"Age":["20","21","22"],"city":["mumbai","pune","gadag"]}
data
# Out:
# {'Name': ['Alice', 'bob', 'charlie'],
#  'Age': ['20', '21', '22'],
#  'city': ['mumbai', 'pune', 'gadag']}

# %%
type(data)
# Out:
# dict

# %% [markdown]
# # creating dataframe

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       Name Age    city
# 0    Alice  20  mumbai
# 1      bob  21     pue
# 2  charlie  22   gadag

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'city'], dtype='object')

# %%
df=pd.DataFrame(data,index=["person1","person2","person3"])
df
# Out:
#             Name Age    city
# person1    Alice  20  mumbai
# person2      bob  21     pue
# person3  charlie  22   gadag

# %%
import pandas as pd
student={"name":["sangeeta","sumant","shree"],"rollno":[11,12,13],"div":["A","B","A"]}
df=pd.DataFrame(student)
df
# Out:
#        name  rollno div
# 0  sangeeta      11   A
# 1    sumant      12   B
# 2     shree      13   A

# %%
df=pd.DataFrame(student,index=["usn1","usn2","usn3"])
df
# Out:
#           name  rollno div
# usn1  sangeeta      11   A
# usn2    sumant      12   B
# usn3     shree      13   A

# %%
df.index
# Out:
# Index(['usn1', 'usn2', 'usn3'], dtype='object')

# %%
df.columns
# Out:
# Index(['name', 'rollno', 'div'], dtype='object')

# %% [markdown]
# # creating dataframe from list

# %%
data=[[1,2,3],[4,5,6]]
data
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
df=pd.DataFrame(data,columns=["A","B","C"],index=["D","E"])
df
# Out:
#    A  B  C
# D  1  2  3
# E  4  5  6

# %%
df.shape
# Out:
# (2, 3)

# %%
df=pd.read_excel("demo.xlsx")

# %%
df
# Out:
#        Name School  Marks
# 0   shubham     SA     65
# 1  sangeeta   GGHS     56
# 2     radha     GT     56
# 3    shreya    KLE     67
# 4   akshata    REC     84

# %%
df=pd.read_json("example.json")
df
# Out:
#     Name    Lang
# 0  Alice  Python
# 1    BOB    HTML

# %%
import numpy as np
arr=np.array([[1,2,3],[4,5,6]])
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
df=pd.DataFrame(arr,columns=["A","B","c"])
df
# Out:
#    A  B  c
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# # viewing data

# %%
import pandas as pd
df = pd.read_csv("leads-100.csv")
df.tail()
# Out:
#     Index       Account Id         Lead Owner First Name  Last Name  \
# 95     96  879AA6f76aCcEeF         Mary Terry      Erica   Garrison
# 96     97  f8EBCd52d798D8f     Vincent Mcneil   Fernando  Dickerson
# 97     98  bcCE5c7bEbdFfB2         Colin Choi     Sheila       Dyer
# 98     99  6cC0Dc8e4410B7E          Tony Beck     Cassie     Conrad
# 99    100  DCabaF160FbDda8  Dillon Stephenson  Charlotte   Browning
#
#                   Company            Phone 1               Phone 2  \
# 95          Clark-Sanford    +1-597-982-7250     (392)732-6167x122
# 96         Gibbs and Sons   001-531-794-3476    215.384.8090x37887
# 97             Frank-Wolf   965-697-8363x869      001-986-382-4669
# 98  Blake, Diaz and Weber  635-429-3322x8976   +1-431-607-4655x365
# 99           Calderon LLC  (430)620-2165x822  +1-818-816-2088x7516
#
#                      Email 1                             Email 2  \
# 95   clairegraves@campos.com             royclarence@navarro.net
# ...

# %%
iris = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
df=pd.read_csv(iris)
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.tail()
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
df.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   5.1          149 non-null    float64
#  1   3.5          149 non-null    float64
#  2   1.4          149 non-null    float64
#  3   0.2          149 non-null    float64
#  4   Iris-setosa  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df.describe()
# Out:
#               5.1         3.5         1.4         0.2
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.shape
# Out:
# (149, 5)

# %% [markdown]
# # DAY - 2

# %% [markdown]
# # data selection

# %%
import pandas as pd

# %%
df=pd.read_csv("data2.csv")
df.tail()
# Out:
#              Actor                      Film  Year            Genre  \
# 7   Hrithik Roshan                       War  2019           Action
# 8     Akshay Kumar                Good Newwz  2019           Comedy
# 9    Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10    Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %% [markdown]
# # selecting column

# %%
df["Actor"]
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
type(df["Actor"])
# Out:
# pandas.core.series.Series

# %%
df[["Actor","IMDb"]]
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
type(df[["Actor","IMDb"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # selecting rows

# %%
df.loc[0]
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Actor                   Shah Rukh Khan
# Film                           Pathaan
# Year                              2023
# Genre                           Action
# BoxOffice(INR Crore)              1050
# IMDb                               7.2
# Name: 0, dtype: object

# %%
df1=pd.DataFrame([[1,2,3],[4,5,7]],columns=["A","B","C"],index=["D","E"])
df1
# Out:
#    A  B  C
# D  1  2  3
# E  4  5  7

# %%
df1.iloc[0] #idex numbers
# Out:
# A    1
# B    2
# C    3
# Name: D, dtype: int64

# %%
df1.loc["E"] # assign letter
# Out:
# A    4
# B    5
# C    7
# Name: E, dtype: int64

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %% [markdown]
# # selecting specific rows and column

# %%
df.loc[0,"Actor"]
# Out:
# 'Shah Rukh Khan'

# %%
df.iloc[0,0]
# Out:
# 'Shah Rukh Khan'

# %%
df.loc[1,"Film"]
# Out:
# 'Tiger Zinda Hai'

# %%
df.iloc[0,1]
# Out:
# 'Pathaan'

# %%
df.loc[0:2,["Actor","IMDb"]]
# Out:
#             Actor  IMDb
# 0  Shah Rukh Khan   7.2
# 1     Salman Khan   6.0
# 2      Aamir Khan   8.4

# %%
df.iloc[0:2,[0,5]]
# Out:
#             Actor  IMDb
# 0  Shah Rukh Khan   7.2
# 1     Salman Khan   6.0

# %%
df.loc[0:2,"Actor":"Genre"]
# Out:
#             Actor             Film  Year      Genre
# 0  Shah Rukh Khan          Pathaan  2023     Action
# 1     Salman Khan  Tiger Zinda Hai  2017     Action
# 2      Aamir Khan           Dangal  2016  Biography

# %%
df.loc[0:5,"Actor":"Genre"]
# Out:
#                 Actor             Film  Year       Genre
# 0      Shah Rukh Khan          Pathaan  2023      Action
# 1         Salman Khan  Tiger Zinda Hai  2017      Action
# 2          Aamir Khan           Dangal  2016   Biography
# 3       Ranbir Kapoor       Brahmastra  2022     Fantasy
# 4       Ranveer Singh        Padmaavat  2018  Historical
# 5  Ayushmann Khurrana        Andhadhun  2018    Thriller

# %%
df.iloc[0:5,[0,1,2,3]]
# Out:
#             Actor             Film  Year       Genre
# 0  Shah Rukh Khan          Pathaan  2023      Action
# 1     Salman Khan  Tiger Zinda Hai  2017      Action
# 2      Aamir Khan           Dangal  2016   Biography
# 3   Ranbir Kapoor       Brahmastra  2022     Fantasy
# 4   Ranveer Singh        Padmaavat  2018  Historical

# %%
df.iloc[0:3,0:4]
# Out:
#             Actor             Film  Year      Genre
# 0  Shah Rukh Khan          Pathaan  2023     Action
# 1     Salman Khan  Tiger Zinda Hai  2017     Action
# 2      Aamir Khan           Dangal  2016  Biography

# %%
df.loc[0:2,"Actor":"Genre"]
# Out:
#             Actor             Film  Year      Genre
# 0  Shah Rukh Khan          Pathaan  2023     Action
# 1     Salman Khan  Tiger Zinda Hai  2017     Action
# 2      Aamir Khan           Dangal  2016  Biography

# %% [markdown]
# # fast access "at" and "iat"

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.at[0,"Actor"]
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[0,0]
# Out:
# 'Shah Rukh Khan'

# %% [markdown]
# # data filtering

# %%
df["IMDb"]>6
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# Name: IMDb, dtype: bool

# %%
df["IMDb"]<6
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# Name: IMDb, dtype: bool

# %%
df[df["IMDb"]>6]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
df[df["IMDb"]<6]
# Out:
#            Actor               Film  Year          Genre  \
# 3  Ranbir Kapoor         Brahmastra  2022        Fantasy
# 9  Kartik Aaryan  Bhool Bhulaiyaa 2  2022  Horror Comedy
#
#    BoxOffice(INR Crore)  IMDb
# 3                   431   5.6
# 9                   266   5.9

# %%
df[df["Year"]>2017]
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 3        Ranbir Kapoor                Brahmastra  2022        Fantasy
# 4        Ranveer Singh                 Padmaavat  2018     Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 7       Hrithik Roshan                       War  2019         Action
# 8         Akshay Kumar                Good Newwz  2019         Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# ...

# %%
df[(df["Year"]>2017)&(df["IMDb"]>6)]
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 4        Ranveer Singh                 Padmaavat  2018     Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 7       Hrithik Roshan                       War  2019         Action
# 8         Akshay Kumar                Good Newwz  2019         Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
df.query("Year>2017 & IMDb>6")
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 4        Ranveer Singh                 Padmaavat  2018     Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 7       Hrithik Roshan                       War  2019         Action
# 8         Akshay Kumar                Good Newwz  2019         Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
df.query("Year > 2017")
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 3        Ranbir Kapoor                Brahmastra  2022        Fantasy
# 4        Ranveer Singh                 Padmaavat  2018     Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 7       Hrithik Roshan                       War  2019         Action
# 8         Akshay Kumar                Good Newwz  2019         Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# ...

# %%
df.query("Actor== 'Hrithik Roshan'")
# Out:
#             Actor Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 7  Hrithik Roshan  War  2019  Action                   475   6.5

# %%
df.query('Actor=="Hrithik Roshan"')
# Out:
#             Actor Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 7  Hrithik Roshan  War  2019  Action                   475   6.5

# %%
df1=pd.DataFrame([[1,2,3],[4,5,6]],columns=["A B","C","D"])
df1
# Out:
#    A B  C  D
# 0    1  2  3
# 1    4  5  6

# %%
df1.query("`A B`==1")
# Out:
#    A B  C  D
# 0    1  2  3

# %%
year=2017
df.query("Year>@year")
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 3        Ranbir Kapoor                Brahmastra  2022        Fantasy
# 4        Ranveer Singh                 Padmaavat  2018     Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 7       Hrithik Roshan                       War  2019         Action
# 8         Akshay Kumar                Good Newwz  2019         Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# ...

# %%
df.query("2017 < Year < 2023")
# Out:
#                  Actor                      Film  Year          Genre  \
# 3        Ranbir Kapoor                Brahmastra  2022        Fantasy
# 4        Ranveer Singh                 Padmaavat  2018     Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 7       Hrithik Roshan                       War  2019         Action
# 8         Akshay Kumar                Good Newwz  2019         Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 11                   342   8.2

# %%
df.query("Year > 2022")
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %%
df
# Out:
# -----------------------------------------------------------
# NameError                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.query("2017 and 2023")
# Out:
# -----------------------------------------------------------
# NameError                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.query("2017 and 2023")
#
# NameError: name 'df' is not defined
